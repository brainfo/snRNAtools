# %% [markdown]
# ## Calculate correlation between replicates

# %%
### packages
import pandas as pd
import numpy as np

# %%
### import data
data = pd.read_csv('36me3_profile.tab',sep='\t',header=1)

# %%
data
# Out:
#                 bins Unnamed: 1       1.0       2.0       3.0       4.0  \
# 0  filter.SRR6956523      genes  0.022222  0.022347  0.022447  0.022435
# 1  filter.SRR6956522      genes  0.017014  0.017060  0.017018  0.017092
# 2  filter.SRR6956528      genes  0.067366  0.067765  0.068139  0.067791
# 3  filter.SRR6956527      genes  0.027305  0.027460  0.027586  0.027280
# 4  filter.SRR6956526      genes  0.047905  0.048722  0.048934  0.049099
# 5  filter.SRR6956525      genes  0.038426  0.038747  0.038627  0.038845
# 6  filter.SRR6956529      genes  0.121167  0.121259  0.121310  0.121189
#
#         5.0       6.0       7.0       8.0  ...  1391.0  1392.0  1393.0  \
# 0  0.022803  0.022348  0.022445  0.022622  ...     NaN     NaN     NaN
# 1  0.017310  0.017134  0.017127  0.017276  ...     NaN     NaN     NaN
# 2  0.068929  0.067749  0.068259  0.069697  ...     NaN     NaN     NaN
# 3  0.027669  0.027330  0.027402  0.027670  ...     NaN     NaN     NaN
# 4  0.049535  0.048968  0.048755  0.049145  ...     NaN     NaN     NaN
# 5  0.039113  0.038582  0.038308  0.038388  ...     NaN     NaN     NaN
# 6  0.121409  0.121004  0.121053  0.121357  ...     NaN     NaN     NaN
#
#    1394.0  1395.0  1396.0  1397.0  1398.0  1399.0  1400.0
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 6     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [7 rows x 1402 columns]

# %%
## Pearson correlation
from scipy.stats import pearsonr

def tsscor(i):
    data1 = data.iloc[i,2:].array.astype(np.float)
    data2 = data.iloc[i+1,2:].array.astype(np.float)
    corr,_ = pearsonr(data1[~np.isnan(data1)],data2[~np.isnan(data2)])
    print(corr)
    print(corr.dtype)
    return corr

# %%
corr=[]
for i in list(range(0,6,2)):
    corr.append(tsscor(i))
# Out:
# 0.9130580749212864
# float64
# 0.9523131883717973
# float64
# 0.3104324661492219
# float64

# %%
list(range(0,6,2))
# Out:
# [0, 2, 4]
