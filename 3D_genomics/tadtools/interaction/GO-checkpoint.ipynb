# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

import pandas as pd
import re
import numpy as np

# %%
# df = pd.read_csv("Type1_BP.txt",sep='\t')
#df = df.loc[df.Bonferroni<0.05]

fig = make_subplots(
    rows=1, cols=2,
    shared_xaxes=True,
    vertical_spacing=0.03,
    specs=[[{"type": "bar"},{"type": "scatter"}]]
)

fig.add_trace(go.Bar(
    y=[segment.split('~')[1] for segment in df.Term],
    x=df.Count,
    name='Count',
    orientation='h'
))

fig.add_trace(
    go.Scatter(
        x=[segment.split('~')[1] for segment in df.Term],
        y=-np.log(df.Bonferroni),
        name="-log(Bonferroni)",
        line=dict(dash='dot')
    ),
    row=1, col=2
)

# fig.add_trace(
#     go.Table(
#         header=dict(
#             values=["Date", "Number<br>Transactions", "Output<br>Volume (BTC)",
#                     "Market<br>Price", "Hash<br>Rate", "Cost per<br>trans-USD",
#                     "Mining<br>Revenue-USD", "Trasaction<br>fees-BTC"],
#             font=dict(size=10),
#             align="left"
#         ),
#         cells=dict(
#             values=[df[k].tolist() for k in df.columns[1:]],
#             align = "left")
#     ),
#     row=1, col=1
# )
fig.update_layout(template='simple_white',title_text='Biological Process enriched by genes in Type 1 TAD',xaxis = dict(showgrid=False, ticks='inside',mirror=False,showline=True),
                yaxis = dict(showgrid=False, ticks='inside',mirror=False,showline=True),yaxis2=dict(side = 'right'),
                font=dict(size=18),
                  width=1000,
                  height=800,
                 title_x=0.5,
                 showlegend=True)

fig.write_image('test.pdf',scale=1)

# %%
def plot_BP(fname,typen,pathway):
    
    df = pd.read_csv(f"{fname}.txt",sep='\t')
    df = df.loc[df.Bonferroni<0.05]

    fig = make_subplots(
        rows=1, cols=2,
        shared_xaxes=True,
        vertical_spacing=0.03,
        specs=[[{"type": "bar"},{"type": "scatter"}]]
    )

    fig.add_trace(go.Bar(
        y=[segment.split('~')[1] for segment in df.Term].reverse(),
        x=df.Count,
        name='Count',
        orientation='h'
    ))

    fig.add_trace(
        go.Scatter(
            x=-np.log(df.Bonferroni),
            y=[segment.split('~')[1] for segment in df.Term],
            name="-log(Bonferroni)",
            line=dict(dash='dot')
        ),
        row=1, col=2
    )


    fig.update_layout(template='simple_white',title_text=f'{pathway} enriched by genes in Type {typen} TAD',xaxis = dict(showgrid=False, ticks='inside',mirror=False,showline=True),
                yaxis = dict(showgrid=False, ticks='inside',mirror=False,showline=True),yaxis2=dict(side = 'right',showticklabels=False),
                font=dict(size=18),
                  width=1000,
                  height=800,
                 title_x=0.5,
                 showlegend=True)

    fig.write_image(f'{fname}.pdf',scale=1)

# %%
plot_BP('Type1_BP','1','Biological Process')

# %%
# Out:
#            Category                                               Term  Count  \
# 0  GOTERM_BP_DIRECT                           GO:0051301~cell division     64
# 1  GOTERM_BP_DIRECT                              GO:0007049~cell cycle     89
# 2  GOTERM_BP_DIRECT                GO:0007067~mitotic nuclear division     50
# 3  GOTERM_BP_DIRECT                              GO:0006281~DNA repair     52
# 4  GOTERM_BP_DIRECT  GO:0006974~cellular response to DNA damage sti...     63
# 5  GOTERM_BP_DIRECT  GO:0006511~ubiquitin-dependent protein catabol...     31
# 6  GOTERM_BP_DIRECT  GO:0008652~cellular amino acid biosynthetic pr...     11
#
#           %        PValue                                              Genes  \
# 0  4.123711  8.080843e-10  ENSMUSG00000056214, ENSMUSG00000026683, ENSMUS...
# 1  5.734536  2.020410e-09  ENSMUSG00000035437, ENSMUSG00000056214, ENSMUS...
# 2  3.221649  1.228570e-08  ENSMUSG00000019907, ENSMUSG00000026683, ENSMUS...
# 3  3.350515  1.655979e-07  ENSMUSG00000055884, ENSMUSG00000035958, ENSMUS...
# 4  4.059278  1.790831e-07  ENSMUSG00000055884, ENSMUSG00000035958, ENSMUS...
# 5  1.997423  1.021947e-06  ENSMUSG00000058976, ENSMUSG00000040749, ENSMUS...
# 6  0.708763  6.013367e-06  ENSMUSG00000026095, ENSMUSG00000029376, ENSMUS...
#
#    List Total  Pop Hits  Pop Total  Fold Enrichment  Bonferroni  Benjamini  \
# 0        1351       374      18082         2.290338    0.000003   0.000003
# 1        1351       614      18082         1.940049    0.000008   0.000004
# 2        1351       277      18082         2.415913    0.000047   0.000016
# 3        1351       318      18082         2.188605    0.000635   0.000137
# 4        1351       420      18082         2.007624    0.000687   0.000137
# 5        1351       154      18082         2.694214    0.003911   0.000653
# 6        1351        25      18082         5.889030    0.022797   0.003294
#
#         FDR
# 0  0.000003
# 1  0.000004
# 2  0.000016
# 3  0.000137
# 4  0.000137
# 5  0.000651
# 6  0.003282
