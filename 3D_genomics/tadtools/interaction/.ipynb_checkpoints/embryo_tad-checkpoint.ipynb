# %%
import pandas as pd
import itertools
from collections import Counter
import math
import sys
sys.path.insert(0, '/home/data4/jh/data/tools/customized/tadtools/tadtool_pkg')
import utils as ut

# %%
oocyte = pd.read_csv('Oocyte_diamond_insulation.txt',sep='\t')
pn3 = pd.read_csv('PN3_diamond_insulation.txt',sep='\t')
sperm = pd.read_csv('Sperm_diamond_insulation.txt',sep='\t')

# %%
oocyte_BoundStrength = ut.out_boundary(oocyte,'Oocyte',0.05)
pn3_BoundStrength = ut.out_boundary(pn3,'PN3',0.05)
sperm_BoundStrength = ut.out_boundary(sperm,'Sperm',0.05)

# %%
oocyte_true_boundary = ut.filter_boundary(oocyte_BoundStrength)
pn3_true_boundary = ut.filter_boundary(pn3_BoundStrength)
sperm_true_boundary = ut.filter_boundary(sperm_BoundStrength)

# %%
oocyte_tads = ut.to_tads(oocyte_true_boundary,'Oocyte',ut.chromosome)
pn3_tads = ut.to_tads(pn3_true_boundary,'PN3',ut.chromosome)
sperm_tads = ut.to_tads(sperm_true_boundary,'Sperm',ut.chromosome)
